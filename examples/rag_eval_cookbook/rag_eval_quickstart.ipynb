# %% [markdown]
# # rag_eval_kit quickstart
#
# This notebook demonstrates deterministic evaluation of a single RAG response.

# %%
from rag_eval_kit import evaluate_rag_response

question = "What revenue risks are discussed in the filing?"
answer = "Revenue may be affected by customer demand, competition, and cloud spending trends. [Source 1]"
contexts = [
    "Revenue may be affected by lower customer demand, competition, and changes in cloud spending patterns.",
    "The company also discusses operating margin and product transitions.",
]
evaluate_rag_response(question=question, answer=answer, contexts=contexts).to_dict()
